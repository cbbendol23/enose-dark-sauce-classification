# %%
# !pip install --upgrade pip
# !pip install ipykernel
# !pip install seaborn
# !pip install pandas
# Out:
# Requirement already satisfied: pip in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (25.2)
# Requirement already satisfied: ipykernel in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (6.30.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (27.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: six>=1.5 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: seaborn in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Requirement already satisfied: pandas in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install numpy==1.26.4 scipy==1.13.0 scikit-learn==1.7.1
# !pip install scikit-learn matplotlib
# Out:
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\ben\Documents\Thesis\enose-dark-sauce-classification\venv_dark_sauce\Scripts\python.exe C:\Users\ben\AppData\Local\Temp\pip-install-eozcjlas\numpy_565026ba90c84e7abb3ef7a89f185d02\vendored-meson\meson\meson.py setup C:\Users\ben\AppData\Local\Temp\pip-install-eozcjlas\numpy_565026ba90c84e7abb3ef7a89f185d02 C:\Users\ben\AppData\Local\Temp\pip-install-eozcjlas\numpy_565026ba90c84e7abb3ef7a89f185d02\.mesonpy-rxu536h4 -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\ben\AppData\Local\Temp\pip-install-eozcjlas\numpy_565026ba90c84e7abb3ef7a89f185d02\.mesonpy-rxu536h4\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\ben\AppData\Local\Temp\pip-install-eozcjlas\numpy_565026ba90c84e7abb3ef7a89f185d02
#       Build dir: C:\Users\ben\AppData\Local\Temp\pip-install-eozcjlas\numpy_565026ba90c84e7abb3ef7a89f185d02\.mesonpy-rxu536h4
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#       Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#       A full log can be found at C:\Users\ben\AppData\Local\Temp\pip-install-eozcjlas\numpy_565026ba90c84e7abb3ef7a89f185d02\.mesonpy-rxu536h4\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: scikit-learn in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (1.7.1)
# Requirement already satisfied: matplotlib in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (3.10.6)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ben\documents\thesis\enose-dark-sauce-classification\venv_dark_sauce\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score 
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import joblib
from mpl_toolkits.mplot3d import Axes3D

# %%
# Training the Model

main_voc_df = pd.read_csv('final_trainingset_4sensors_new.csv')  
X = main_voc_df.drop(columns=['Label'])
y = main_voc_df['Label']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

svm_classifier = SVC(
    class_weight='balanced',
    random_state=42
)

model_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=None)),
    ('classifier', svm_classifier)
])

param_grid = {
    'classifier__kernel': ['rbf'], ## , 'poly']
    'classifier__C': [0.1, 1, 10],
    'classifier__gamma': [0.001, 0.01, 0.1, 1, 10],
    ## 'classifier__degree': [2, 3, 4],
    'pca__n_components': [2, 3]
}

grid_search = GridSearchCV(model_pipeline, param_grid, cv=5, n_jobs=1)
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_

# %%
joblib.dump(best_model, 'svm_best_model_RBF.joblib')
print('Model saved as svm_best_model.joblib.')
# Out:
# Model saved as svm_best_model.joblib.

# %%
melted_df = main_voc_df.melt(
    id_vars="Label",
    value_vars=[col for col in main_voc_df.columns if "MQ" in col],
    var_name="Sensor",
    value_name="Value"
)

plt.figure(figsize=(12, 6))
sns.barplot(
    data=melted_df,
    x="Sensor",
    y="Value",
    hue="Label",
    ci=None,
    palette="Set2"
)

plt.title("Average MQ Sensor Values per Sauce")
plt.ylabel("Mean Sensor Reading")
plt.xlabel("MQ Sensor")
plt.xticks(rotation=45)
plt.legend(title="Condiment")
plt.tight_layout()
plt.show()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA (n = 2) plot
pca_2d = PCA(n_components=2)
X_pca_2d = pca_2d.fit_transform(X_scaled)
pca_df_2d = pd.DataFrame(X_pca_2d, columns=["PC1", "PC2"])
pca_df_2d['Label'] = y.values

plt.figure(figsize=(8, 6))
sns.scatterplot(data=pca_df_2d, x="PC1", y="PC2", hue="Label", palette="Set2", s=70)
plt.title("Data after PCA (2 Components)")
plt.legend(title="Sauce Type")
plt.tight_layout()
plt.show()

# PCA ( = 3) plot
pca_3d = PCA(n_components=3)
X_pca_3d = pca_3d.fit_transform(X_scaled)
pca_df_3d = pd.DataFrame(X_pca_3d, columns=["PC1", "PC2", "PC3"])
pca_df_3d['Label'] = y.values

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
for label in pca_df_3d['Label'].unique():
    subset = pca_df_3d[pca_df_3d['Label'] == label]
    ax.scatter(subset['PC1'], subset['PC2'], subset['PC3'], label=label, s=60)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('3D PCA Scatter Plot (3 Components)')
ax.legend(title='Sauce Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ben\AppData\Local\Temp\ipykernel_8544\2289986022.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
# Evaluate model on test set
predictions = best_model.predict(X_test)

accuracy = accuracy_score(y_test, predictions)
f1_macro = f1_score(y_test, predictions, average='macro')

best_params_df = pd.DataFrame(
    list(grid_search.best_params_.items()),
    columns=['Hyperparameter', 'Value']
 )
print("\nBest Hyperparameters:")
display(best_params_df)

metrics_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Macro F1 Score'],
    'Value': [f"{accuracy:.4f}", f"{f1_macro:.4f}"]
})
print("\nEvaluation Metrics (Test Set):")
display(metrics_df)

print("\nClassification Report:")
print(classification_report(y_test, predictions, target_names=y_test.unique()))

labels = y_test.unique()  # Preserves label order from test set
conf_matrix = confusion_matrix(y_test, predictions, labels=labels)

disp = ConfusionMatrixDisplay(conf_matrix, display_labels=labels)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix - SVM (Test Set)")
plt.tight_layout()
plt.show()

results_df = pd.DataFrame({
    'True Label': y_test,
    'Predicted Label': predictions
})
results_df['Correct'] = results_df['True Label'] == results_df['Predicted Label']

misclassified = results_df[~results_df['Correct']]

print("\nMisclassified Trials:")
display(misclassified)

print("\nAll Predictions:")
display(results_df)
# Out:
# Best Hyperparameters:
#        Hyperparameter Value
# 0       classifier__C     1
# 1   classifier__gamma    10
# 2  classifier__kernel   rbf
# 3   pca__n_components     2
# Evaluation Metrics (Test Set):
#            Metric   Value
# 0        Accuracy  1.0000
# 1  Macro F1 Score  1.0000
# Classification Report:
#                       precision    recall  f1-score   support
#
#         Oyster Sauce       1.00      1.00      1.00         9
#           Fish Sauce       1.00      1.00      1.00         9
#            Soy Sauce       1.00      1.00      1.00        10
# Worcestershire Sauce       1.00      1.00      1.00         9
#
#             accuracy                           1.00        37
#            macro avg       1.00      1.00      1.00        37
#         weighted avg       1.00      1.00      1.00        37
# Misclassified Trials:
# Empty DataFrame
# Columns: [True Label, Predicted Label, Correct]
# Index: []
# All Predictions:
#                True Label       Predicted Label  Correct
# 80           Oyster Sauce          Oyster Sauce     True
# 86           Oyster Sauce          Oyster Sauce     True
# 89           Oyster Sauce          Oyster Sauce     True
# 41             Fish Sauce            Fish Sauce     True
# 76           Oyster Sauce          Oyster Sauce     True
# 7               Soy Sauce             Soy Sauce     True
# 103  Worcestershire Sauce  Worcestershire Sauce     True
# 75           Oyster Sauce          Oyster Sauce     True
# 59             Fish Sauce            Fish Sauce     True
# 28              Soy Sauce             Soy Sauce     True
# 118  Worcestershire Sauce  Worcestershire Sauce     True
# 70           Oyster Sauce          Oyster Sauce     True
# 14              Soy Sauce             Soy Sauce     True
# 3               Soy Sauce             Soy Sauce     True
# 114  Worcestershire Sauce  Worcestershire Sauce     True
# 45             Fish Sauce            Fish Sauce     True
# 99   Worcestershire Sauce  Worcestershire Sauce     True
# 108  Worcestershire Sauce  Worcestershire Sauce     True
# 72           Oyster Sauce          Oyster Sauce     True
# 37             Fish Sauce            Fish Sauce     True
# 38             Fish Sauce            Fish Sauce     True
# 111  Worcestershire Sauce  Worcestershire Sauce     True
# 16              Soy Sauce             Soy Sauce     True
# 120  Worcestershire Sauce  Worcestershire Sauce     True
# 17              Soy Sauce             Soy Sauce     True
# 11              Soy Sauce             Soy Sauce     True
# 58             Fish Sauce            Fish Sauce     True
# 51             Fish Sauce            Fish Sauce     True
# 2               Soy Sauce             Soy Sauce     True
# 13              Soy Sauce             Soy Sauce     True
# 6               Soy Sauce             Soy Sauce     True
# 105  Worcestershire Sauce  Worcestershire Sauce     True
# 106  Worcestershire Sauce  Worcestershire Sauce     True
# 88           Oyster Sauce          Oyster Sauce     True
# 49             Fish Sauce            Fish Sauce     True
# 53             Fish Sauce            Fish Sauce     True
# 79           Oyster Sauce          Oyster Sauce     True

# %%
# Predict labels for unseen data (features only, no metrics)
unseen_df = pd.read_csv('gathered_data.csv')
if 'Label' in unseen_df.columns:
    X_unseen = unseen_df.drop(columns=['Label'])
else:
    X_unseen = unseen_df

predictions = best_model.predict(X_unseen)

predicted_df = pd.DataFrame({
    'Predicted Label': predictions
})
print("Predicted Labels for Unseen Data:")
display(predicted_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[134], line 8
#       5 else:
#       6     X_unseen = unseen_df
# ----> 8 predictions = best_model.predict(X_unseen)
#      10 predicted_df = pd.DataFrame({
#      11     'Predicted Label': predictions
#      12 })
#      13 print("Predicted Labels for Unseen Data:")
#
# File c:\Users\ben\Documents\Thesis\enose-dark-sauce-classification\venv_dark_sauce\Lib\site-packages\sklearn\pipeline.py:788, in Pipeline.predict(self, X, **params)
#     786 if not _routing_enabled():
#     787     for _, name, transform in self._iter(with_final=False):
# --> 788         Xt = transform.transform(Xt)
#     789     return self.steps[-1][1].predict(Xt, **params)
#     791 # metadata routing enabled
#
# File c:\Users\ben\Documents\Thesis\enose-dark-sauce-classification\venv_dark_sauce\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File c:\Users\ben\Documents\Thesis\enose-dark-sauce-classification\venv_dark_sauce\Lib\site-packages\sklearn\decomposition\_base.py:138, in _BasePCA.transform(self, X)
#     134 xp, _ = get_namespace(X, self.components_, self.explained_variance_)
#     136 check_is_fitted(self)
# --> 138 X = validate_data(
#     139     self,
#     140     X,
#     141     dtype=[xp.float64, xp.float32],
#     142     accept_sparse=("csr", "csc"),
#     143     reset=False,
#     144 )
#     145 return self._transform(X, xp=xp, x_is_centered=False)
#
# File c:\Users\ben\Documents\Thesis\enose-dark-sauce-classification\venv_dark_sauce\Lib\site-packages\sklearn\utils\validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File c:\Users\ben\Documents\Thesis\enose-dark-sauce-classification\venv_dark_sauce\Lib\site-packages\sklearn\utils\validation.py:1105, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1099     raise ValueError(
#    1100         f"Found array with dim {array.ndim},"
#    1101         f" while dim <= 2 is required{context}."
#    1102     )
#    1104 if ensure_all_finite:
# -> 1105     _assert_all_finite(
#    1106         array,
#    1107         input_name=input_name,
#    1108         estimator_name=estimator_name,
#    1109         allow_nan=ensure_all_finite == "allow-nan",
#    1110     )
#    1112 if copy:
#    1113     if _is_numpy_namespace(xp):
#    1114         # only make a copy if `array` and `array_orig` may share memory`
#
# File c:\Users\ben\Documents\Thesis\enose-dark-sauce-classification\venv_dark_sauce\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File c:\Users\ben\Documents\Thesis\enose-dark-sauce-classification\venv_dark_sauce\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# PCA does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
# Predict labels for unseen data (features only, no metrics)
unseen_df = pd.read_csv('fish_sauce_validation.csv')
if 'Label' in unseen_df.columns:
    X_unseen = unseen_df.drop(columns=['Label'])
else:
    X_unseen = unseen_df

predictions = best_model.predict(X_unseen)

predicted_df = pd.DataFrame({
    'Predicted Label': predictions
})
print("Predicted Labels for Unseen Data:")
pd.set_option('display.max_rows', None)
display(predicted_df)
# Out:
# Predicted Labels for Unseen Data:
#           Predicted Label
# 0              Fish Sauce
# 1            Oyster Sauce
# 2            Oyster Sauce
# 3              Fish Sauce
# 4              Fish Sauce
# 5              Fish Sauce
# 6              Fish Sauce
# 7            Oyster Sauce
# 8            Oyster Sauce
# 9              Fish Sauce
# 10             Fish Sauce
# 11             Fish Sauce
# 12             Fish Sauce
# 13             Fish Sauce
# 14             Fish Sauce
# 15              Soy Sauce
# 16              Soy Sauce
# 17              Soy Sauce
# 18              Soy Sauce
# 19              Soy Sauce
# 20              Soy Sauce
# 21              Soy Sauce
# 22              Soy Sauce
# 23              Soy Sauce
# 24              Soy Sauce
# 25              Soy Sauce
# 26              Soy Sauce
# 27              Soy Sauce
# 28              Soy Sauce
# 29              Soy Sauce
# 30              Soy Sauce
# 31              Soy Sauce
# 32              Soy Sauce
# 33              Soy Sauce
# 34              Soy Sauce
# 35              Soy Sauce
# 36              Soy Sauce
# 37              Soy Sauce
# 38              Soy Sauce
# 39              Soy Sauce
# 40              Soy Sauce
# 41              Soy Sauce
# 42              Soy Sauce
# 43              Soy Sauce
# 44              Soy Sauce
# 45              Soy Sauce
# 46           Oyster Sauce
# 47           Oyster Sauce
# 48           Oyster Sauce
# 49           Oyster Sauce
# 50           Oyster Sauce
# 51           Oyster Sauce
# 52           Oyster Sauce
# 53           Oyster Sauce
# 54           Oyster Sauce
# 55           Oyster Sauce
# 56           Oyster Sauce
# 57           Oyster Sauce
# 58           Oyster Sauce
# 59           Oyster Sauce
# 60           Oyster Sauce
# 61           Oyster Sauce
# 62           Oyster Sauce
# 63           Oyster Sauce
# 64           Oyster Sauce
# 65           Oyster Sauce
# 66           Oyster Sauce
# 67           Oyster Sauce
# 68           Oyster Sauce
# 69           Oyster Sauce
# 70           Oyster Sauce
# 71           Oyster Sauce
# 72           Oyster Sauce
# 73           Oyster Sauce
# 74           Oyster Sauce
# 75           Oyster Sauce
# 76           Oyster Sauce
# 77           Oyster Sauce
# 78           Oyster Sauce
# 79   Worcestershire Sauce
# 80   Worcestershire Sauce
# 81   Worcestershire Sauce
# 82   Worcestershire Sauce
# 83   Worcestershire Sauce
# 84   Worcestershire Sauce
# 85   Worcestershire Sauce
# 86   Worcestershire Sauce
# 87   Worcestershire Sauce
# 88   Worcestershire Sauce
# 89   Worcestershire Sauce
# 90   Worcestershire Sauce
# 91   Worcestershire Sauce
# 92   Worcestershire Sauce
# 93   Worcestershire Sauce
# 94   Worcestershire Sauce
# 95   Worcestershire Sauce
# 96   Worcestershire Sauce
# 97   Worcestershire Sauce
# 98   Worcestershire Sauce
# 99   Worcestershire Sauce
# 100  Worcestershire Sauce
# 101  Worcestershire Sauce
# 102  Worcestershire Sauce
# 103  Worcestershire Sauce
# 104  Worcestershire Sauce
# 105  Worcestershire Sauce
# 106  Worcestershire Sauce
# 107  Worcestershire Sauce
# 108  Worcestershire Sauce

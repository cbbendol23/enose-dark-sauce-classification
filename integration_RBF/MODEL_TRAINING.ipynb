# %%
# !pip install --upgrade pip
# !pip install ipykernel
# !pip install seaborn
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\lib\site-packages (25.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipykernel in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (6.30.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: six>=1.5 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install numpy==1.26.4 scipy==1.13.0 scikit-learn==1.4.2
# !pip install scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#       + C:\Users\acotj\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe C:\Users\acotj\AppData\Local\Temp\pip-install-wxarn1c_\numpy_9563fe9fdce44471b6092f404932e7ae\vendored-meson\meson\meson.py setup C:\Users\acotj\AppData\Local\Temp\pip-install-wxarn1c_\numpy_9563fe9fdce44471b6092f404932e7ae C:\Users\acotj\AppData\Local\Temp\pip-install-wxarn1c_\numpy_9563fe9fdce44471b6092f404932e7ae\.mesonpy-bgp1oj3j -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\acotj\AppData\Local\Temp\pip-install-wxarn1c_\numpy_9563fe9fdce44471b6092f404932e7ae\.mesonpy-bgp1oj3j\meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.99
#       Source dir: C:\Users\acotj\AppData\Local\Temp\pip-install-wxarn1c_\numpy_9563fe9fdce44471b6092f404932e7ae
#       Build dir: C:\Users\acotj\AppData\Local\Temp\pip-install-wxarn1c_\numpy_9563fe9fdce44471b6092f404932e7ae\.mesonpy-bgp1oj3j
#       Build type: native build
#       Project name: NumPy
#       Project version: 1.26.4
#       WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#       ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#       The following exception(s) were encountered:
#       Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#       Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#       Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#       Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#       A full log can be found at C:\Users\acotj\AppData\Local\Temp\pip-install-wxarn1c_\numpy_9563fe9fdce44471b6092f404932e7ae\.mesonpy-bgp1oj3j\meson-logs\meson-log.txt
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (3.10.6)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\acotj\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report,confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score 
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import joblib

# %%
# Training the Model

main_voc_df = pd.read_csv('final_trainingset.csv')  
X = main_voc_df.drop(columns=['Label'])
y = main_voc_df['Label']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

svm_classifier = SVC(
    class_weight='balanced',
    random_state=42
)

model_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=None)),
    ('classifier', svm_classifier)
])

param_grid = {
    'classifier__kernel': ['rbf'], ##, 'poly'
    'classifier__C': [0.1, 1, 10, 100, 1000],
    'classifier__gamma': [0.001, 0.01, 0.1, 1, 10],
    ## 'classifier__degree': [2, 3, 4],
    'pca__n_components': [2, 3],
}

grid_search = GridSearchCV(model_pipeline, param_grid, cv=3, n_jobs=1)
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_

# %%
joblib.dump(best_model, 'svm_best_model_RBF.joblib')
print('Model saved as svm_best_model.joblib.')
# Out:
# Model saved as svm_best_model.joblib.

# %%
melted_df = main_voc_df.melt(
    id_vars="Label",
    value_vars=[col for col in main_voc_df.columns if "MQ" in col],
    var_name="Sensor",
    value_name="Value"
)

plt.figure(figsize=(12, 6))
sns.barplot(
    data=melted_df,
    x="Sensor",
    y="Value",
    hue="Label",
    ci=None,
    palette="Set2"
)

plt.title("Average MQ Sensor Values per Sauce")
plt.ylabel("Mean Sensor Reading")
plt.xlabel("MQ Sensor")
plt.xticks(rotation=45)
plt.legend(title="Condiment")
plt.tight_layout()
plt.show()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
pca_df = pd.DataFrame(X_pca, columns=["PC1", "PC2"])
pca_df['Label'] = y.values

plt.figure(figsize=(8, 6))
sns.scatterplot(data=pca_df, x="PC1", y="PC2", hue="Label", palette="Set2", s=70)
plt.title("Data after PCA (2 Components)")
plt.legend(title="Sauce Type")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\acotj\AppData\Local\Temp\ipykernel_31232\130573307.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
new_df = pd.read_csv('final_trainingset.csv')
X_new = new_df.drop(columns=['Label'])
Y_new = new_df['Label']

predictions = best_model.predict(X_new)

accuracy = accuracy_score(Y_new, predictions)
f1_macro = f1_score(Y_new, predictions, average='macro')

best_params_df = pd.DataFrame(
    list(grid_search.best_params_.items()),
    columns=['Hyperparameter', 'Value']
)
print("\nBest Hyperparameters:")
display(best_params_df)

metrics_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Macro F1 Score'],
    'Value': [f"{accuracy:.4f}", f"{f1_macro:.4f}"]
})
print("\nEvaluation Metrics (Unseen Data):")
display(metrics_df)

print("\nClassification Report:")
print(classification_report(Y_new, predictions, target_names=Y_new.unique()))

labels = Y_new.unique()  # Preserves label order from CSV
conf_matrix = confusion_matrix(Y_new, predictions, labels=labels)

disp = ConfusionMatrixDisplay(conf_matrix, display_labels=labels)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix - SVM (Unseen Data)")
plt.tight_layout()
plt.show()


results_df = pd.DataFrame({
    'True Label': Y_new,
    'Predicted Label': predictions
})
results_df['Correct'] = results_df['True Label'] == results_df['Predicted Label']

misclassified = results_df[~results_df['Correct']]

print("\nMisclassified Trials:")
display(misclassified)

print("\nAll Predictions:")
display(results_df)
#
# Out:
# Best Hyperparameters:
#        Hyperparameter Value
# 0       classifier__C  1000
# 1   classifier__gamma     1
# 2  classifier__kernel   rbf
# 3   pca__n_components     2
# Evaluation Metrics (Unseen Data):
#            Metric   Value
# 0        Accuracy  0.9917
# 1  Macro F1 Score  0.9917
# Classification Report:
#                       precision    recall  f1-score   support
#
#            Soy Sauce       1.00      0.97      0.98        30
#           Fish Sauce       0.97      1.00      0.98        30
#         Oyster Sauce       1.00      1.00      1.00        31
# Worcestershire Sauce       1.00      1.00      1.00        30
#
#             accuracy                           0.99       121
#            macro avg       0.99      0.99      0.99       121
#         weighted avg       0.99      0.99      0.99       121
# Misclassified Trials:
#     True Label Predicted Label  Correct
# 52  Fish Sauce    Oyster Sauce    False
# All Predictions:
#                True Label       Predicted Label  Correct
# 0               Soy Sauce             Soy Sauce     True
# 1               Soy Sauce             Soy Sauce     True
# 2               Soy Sauce             Soy Sauce     True
# 3               Soy Sauce             Soy Sauce     True
# 4               Soy Sauce             Soy Sauce     True
# ..                    ...                   ...      ...
# 116  Worcestershire Sauce  Worcestershire Sauce     True
# 117  Worcestershire Sauce  Worcestershire Sauce     True
# 118  Worcestershire Sauce  Worcestershire Sauce     True
# 119  Worcestershire Sauce  Worcestershire Sauce     True
# 120  Worcestershire Sauce  Worcestershire Sauce     True
#
# [121 rows x 3 columns]
